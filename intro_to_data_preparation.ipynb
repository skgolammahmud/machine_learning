# %%
# 🔑 ডেটা প্রিপারেশনের প্রধান ধাপগুলো

# ১. ডুপ্লিকেট ডেটা চেক ও সরানো
#    → অনেক সময় একই ডেটা একাধিকবার থাকে, এগুলো সরিয়ে ফেলতে হয়।

# ২. মিসিং ভ্যালু হ্যান্ডেল করা
#    → ডেটা খালি থাকতে পারে। তখন তিনটি উপায় থাকে:
#       • খালি রো মুছে ফেলা
#       • খালি মান পূরণ করা (যেমন গড়/median দিয়ে)
#       • রেখে দেওয়া (যদি dataset বড় হয় এবং missing খুব কম থাকে)

# ৩. Noise বা অপ্রয়োজনীয় ফিচার সরানো
#    → যেসব feature prediction-এ সাহায্য করে না, সেগুলো বাদ দিতে হয়।

# ৪. Feature format ঠিক করা
#    → Numeric column-এ যেন text না থাকে।
#    → Image dataset হলে সব image ঠিক ফরম্যাটে (jpg/png) থাকতে হবে।

# ৫. Categorical data encode করা
#    → যেমন: "male" / "female" → 0 / 1

# ৬. নতুন ফিচার তৈরি করা (Feature Engineering)
#    → এটি সৃজনশীল কাজ। সঠিকভাবে করা হলে মডেলের পারফরম্যান্স অনেক বেড়ে যায়।

# ৭. Scaling / Normalization করা
#    → Numeric features খুব বড় মানের হলে model train করতে সমস্যা হয়।
#       • Normalization: সব মানকে 0 থেকে 1 এর মধ্যে আনা
#       • Standardization: mean = 0, std = 1 করে scale করা

# ৮. Shuffling এবং Splitting
#    → Dataset কে randomize করা
#    → Train, Validation, Test set-এ ভাগ করা
